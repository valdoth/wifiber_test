# %%
import pandas as pd

# %%
df = pd.read_excel("../data/CPT vers TDD.xlsx")

# %%
df.head()
# Out:
#    Année Mois    Custcode date_activation           raison  \
# 0   2024  mai  1.04525484      2024-05-30  CPT IE vers TDD
# 1   2024  mai  1.04533082      2024-05-24  CPT IE vers TDD
# 2   2024  mai  1.10323289      2024-05-24  CPT IE vers TDD
# 3   2024  mai  1.10647209      2024-05-07  CPT IE vers TDD
# 4   2024  mai  1.11228788      2024-05-22  CPT IE vers TDD
#
#    date_desactivation cciale      segm        msisdn  \
# 0                 NaN    daj       SME  261320562772
# 1                 NaN    dsn       SME  261320762003
# 2                 NaN    daj       SME  261321210360
# 3                 NaN    nvo  TPE/SOHO  261320539426
# 4                 NaN    ang       SME  261321132485
#
#                                nom client     rateplan Catégorie  statut  \
# 0  Societe Mer et Nature Antoremba Lodge   WIfiber Pro  internet  Activ°
# 1                        Societe MI KIRY   WIfiber Pro  internet  Activ°
# ...

# %%
cpt = df[["Année", "Mois", "Custcode", "date_activation", "msisdn", "rateplan" , "Engagement", "Bundle"]]

# %%
cpt.head()
# Out:
#    Année Mois    Custcode date_activation        msisdn     rateplan  \
# 0   2024  mai  1.04525484      2024-05-30  261320562772  WIfiber Pro
# 1   2024  mai  1.04533082      2024-05-24  261320762003  WIfiber Pro
# 2   2024  mai  1.10323289      2024-05-24  261321210360  WIfiber Pro
# 3   2024  mai  1.10647209      2024-05-07  261320539426  WIfiber Pro
# 4   2024  mai  1.11228788      2024-05-22  261321132485  WIfiber Pro
#
#    Engagement              Bundle
# 0          24  WIfiber Pro-Medium
# 1          24  WIfiber Pro-Medium
# 2          24  WIfiber Pro-Medium
# 3          24  WIfiber Pro-Medium
# 4          12  WIfiber Pro-Medium

# %%
cpt["Bundle"].unique()
# Out:
# array(['WIfiber Pro-Medium', 'WIfiber Pro-Plus', 'WIfiber Pro-Start+',
#        'Wifiber Pro-Start+', nan], dtype=object)

# %%
cpt["rateplan"].unique()
# Out:
# array(['WIfiber Pro'], dtype=object)
